# %% [markdown]
# <a href="https://colab.research.google.com/github/XAI-liacs/BLADE/blob/feature%2Fcodex-create-tutorials-for-jupyter-notebooks/docs/notebooks/getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BLADE Minimal Example.
# * In this example, we will implement a simple LLM based optimisation algorithm on `MABBOB` or Many-Affine Black-Box Optimisation Benchamrking, with help of different LLM prompts, and test their relative performance.

# %% [markdown]
# ## Setting Up...
# - Get an API Key from [Gemini](https://aistudio.google.com/apikey), we will be using gemini for this experiment.
# - Copy that API Key and go to `Secrets` tab on the sidebar $\leftarrow$:
#   - Set `Name` to `GEMINI_API_KEY`
#   - Paste the API Key into `Value` section.
#   - Activate the notebook access toggle.

# %%
# !pip install swig
# !pip install iohblade
# Out:
# Collecting swig
#   Downloading swig-4.3.1.post0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.1.post0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.8 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.3.1.post0
# Collecting llamea
#   Downloading llamea-1.1.0-py3-none-any.whl.metadata (17 kB)
# Collecting configspace<2,>=1.2.0 (from llamea)
#   Downloading configspace-1.2.1.tar.gz (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 9.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-generativeai<0.9,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from llamea) (0.8.5)
# Requirement already satisfied: joblib<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from llamea) (1.5.1)
# Collecting jsonlines<5,>=4.0.0 (from llamea)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting numpy<2,>=1.26.3 (from llamea)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# Collecting ollama<0.3,>=0.2.1 (from llamea)
#   Downloading ollama-0.2.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: openai<2,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from llamea) (1.100.0)
# Collecting pandas==2.0.3 (from llamea)
#   Downloading pandas-2.0.3.tar.gz (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 46.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm<5,>=4.66.4 in /usr/local/lib/python3.12/dist-packages (from llamea) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.0.3->llamea) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.0.3->llamea) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.0.3->llamea) (2025.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from configspace<2,>=1.2.0->llamea) (3.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from configspace<2,>=1.2.0->llamea) (1.16.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from configspace<2,>=1.2.0->llamea) (4.14.1)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from configspace<2,>=1.2.0->llamea) (10.7.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai<0.9,>=0.8.1->llamea) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai<0.9,>=0.8.1->llamea) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai<0.9,>=0.8.1->llamea) (2.179.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai<0.9,>=0.8.1->llamea) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai<0.9,>=0.8.1->llamea) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai<0.9,>=0.8.1->llamea) (2.11.7)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai<0.9,>=0.8.1->llamea) (1.26.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines<5,>=4.0.0->llamea) (25.3.0)
# Collecting httpx<0.28.0,>=0.27.0 (from ollama<0.3,>=0.2.1->llamea)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.25.2->llamea) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.25.2->llamea) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.25.2->llamea) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2,>=1.25.2->llamea) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<2,>=1.25.2->llamea) (3.10)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai<0.9,>=0.8.1->llamea) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai<0.9,>=0.8.1->llamea) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9,>=0.8.1->llamea) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9,>=0.8.1->llamea) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai<0.9,>=0.8.1->llamea) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<0.3,>=0.2.1->llamea) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<0.3,>=0.2.1->llamea) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama<0.3,>=0.2.1->llamea) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai<0.9,>=0.8.1->llamea) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai<0.9,>=0.8.1->llamea) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai<0.9,>=0.8.1->llamea) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3->llamea) (1.17.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai<0.9,>=0.8.1->llamea) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai<0.9,>=0.8.1->llamea) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai<0.9,>=0.8.1->llamea) (4.2.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9,>=0.8.1->llamea) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai<0.9,>=0.8.1->llamea) (1.71.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9,>=0.8.1->llamea) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9,>=0.8.1->llamea) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai<0.9,>=0.8.1->llamea) (2.5.0)
# Downloading llamea-1.1.0-py3-none-any.whl (23 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 82.6 MB/s eta 0:00:00
# Downloading ollama-0.2.1-py3-none-any.whl (9.7 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: pandas, configspace

# %% [markdown]
# ## Library Overview.
# * The iohblade has:
#   * `.experiments` that has a list of experiments to choose from to benchmark said algorithm.
#   * `.llm` which is an interface that allows the optimisers to interact with the LLM like *Gemini, OLLAMA, OpenAI,*$\ldots$
#   * `.methods` are search methods that include *LLaMEA	Large Langugage Model Evolutionary Algorithm, Evolution of Heuristics, FunSearch, ReEvo	Large Language Models as Hyper-Heuristics with Reflective Evolution*.
#   * `.loggers` help logging experiment data to run analysis on.

# %%
from iohblade.experiment import MA_BBOB_Experiment
from iohblade.llm import Gemini_LLM
from iohblade.methods import LLaMEA
from iohblade.loggers import ExperimentLogger

from google.colab import userdata

apikey = userdata.get("GEMINI_API_KEY")
ai_model = "gemini-2.5-flash"
llm = Gemini_LLM(apikey, ai_model)
budget = 20 #Small Budget.

# %% [markdown]
# ## Task Prompt
# * The LLMs have often performed measurably distinctly depending on the prompt that is provided. When using different prompts iteratively, this can cause a lot of divergence in the final result.
# * Following are the mutation prompts that we test against each other, with their intended mutation size:
#   * `Small mutation`: Refine the strategy of the selected algorithm to improve it.
#   * `New individual`: Generate a new algorithm that is different from the algorithms you have tried before.
#   * `Refinement (really small)`: Refine and simplify the selected algorithm to improve it.

# %%
mutation_prompt_1 = ["Refine the strategy of the selected algorithm to improve it."]
mutation_prompt_2 = ["Generate a new algorithm that is different from the algorithms you have tried before."]
mutation_prompt_3 = ["Refine and simplify the selected algorithm to improve it."]

# %% [markdown]
# ## Implement optimiser.
# * Now using `LLaMEA`, we implement $(4, 12)$--4 parents ($\mu$) and 12 offsprings ($\lambda$) evolutionary strategy to test the performance difference between

# %%
LLaMEA_1 = LLaMEA(llm, budget=budget, name= "LLaMEA-small_mutation", mutation_prompts=mutation_prompt_1, n_parents=1, n_offspring=1, elitism=True)
LLaMEA_2 = LLaMEA(llm, budget=budget, name= "LLaMEA-new_individual", mutation_prompts=mutation_prompt_2, n_parents=2, n_offspring=4, elitism=True)
LLaMEA_3 = LLaMEA(llm, budget=budget, name= "LLaMEA-fine-mutation", mutation_prompts=mutation_prompt_3, n_parents=2, n_offspring=6, elitism=False)

methods = [LLaMEA_1, LLaMEA_2, LLaMEA_3]

# %% [markdown]
# ## Run Experiment
# * We now use `ExperimentLogger` from `iohblade` to log relevant data for analysis of the algorithms.
# * Initialise the `MA_BBOB_Experiment` and run the experiement.
# * ! **WARNING** Running the next cell might incur API costs and will also take several hours to run. You can also skip this step and download the results next.
#
# <div class="alert alert-block alert-warning">
# <b>Warning:</b> The next step might take several hours to run (depending on the budget and number of runs)
# </div>

# %%
logger = ExperimentLogger("MA-BBOB")
experiment = MA_BBOB_Experiment(methods=methods, runs=1, seeds=[4], dims=[5], budget_factor=2000, budget=budget, eval_timeout=60, show_stdout=True, exp_logger=logger) #normal run
experiment()

# %% [markdown]
# ## Save and Download/Upload the run (optional run)
# * Instead of running a whole set of experiments (such as the above cell), you can also just download the results we prepared for you:
# https://www.dropbox.com/scl/fi/570ucy35verhv6653ey4i/MA-BBOB.zip?rlkey=80ji34uy4amjhbwj3dkv9nx3d&dl=0
# * Upload that *.zip file back up when ready for experiment visualisation, from $\leftarrow$ Files tab.
# * Run the next cell to unzip the file.

# %%
# !unzip /content/MA-BBOB.zip -d /content/MA-BBOB
# Out:
# Archive:  /content/MA-BBOB.zip
#    creating: /content/MA-BBOB/content/MA-BBOB/
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-new_individual-MA_BBOB-7/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-new_individual-MA_BBOB-7/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-new_individual-MA_BBOB-7/log.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/experimentlog.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-small_mutation-MA_BBOB-7/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-small_mutation-MA_BBOB-7/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-small_mutation-MA_BBOB-7/log.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/progress.json
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-full_ensamble-MA_BBOB-4/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-full_ensamble-MA_BBOB-4/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-full_ensamble-MA_BBOB-4/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation-MA_BBOB-7/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation-MA_BBOB-7/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation-MA_BBOB-7/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-new_individual-MA_BBOB-4/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-new_individual-MA_BBOB-4/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-new_individual-MA_BBOB-4/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation+new_individual-MA_BBOB-4/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation+new_individual-MA_BBOB-4/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation+new_individual-MA_BBOB-4/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation+new_individual-MA_BBOB-7/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation+new_individual-MA_BBOB-7/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation+new_individual-MA_BBOB-7/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-full_ensamble-MA_BBOB-7/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-full_ensamble-MA_BBOB-7/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-full_ensamble-MA_BBOB-7/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation-MA_BBOB-4/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation-MA_BBOB-4/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-fine-mutation-MA_BBOB-4/log.jsonl
#    creating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-small_mutation-MA_BBOB-4/
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-small_mutation-MA_BBOB-4/conversationlog.jsonl
#   inflating: /content/MA-BBOB/content/MA-BBOB/run-LLaMEA-small_mutation-MA_BBOB-4/log.jsonl

# %% [markdown]
# # Visualisation
# * The `iohblade` comes with many plots and references to measure algorithm performance. We will use some of them to analyse the experiment data obtained above:
#   * `plot_convergence`: Plots convergence of the algorithm, i.e. `evaluation count v fitness` plots.
#   * `plot_experiment_CEG`: Plot the Code evolution graphs for each run in an experiment, splitted by problem, it is a plot of `evaluation v count` for ach run of each experiment.

# %%
from iohblade import plot_convergence, plot_experiment_CEG

logger = ExperimentLogger("MA-BBOB")
methods, problems = logger.get_methods_problems()
display(methods, problems)
# Out:
# ['LLaMEA-fine-mutation',
#  'LLaMEA-fine-mutation+new_individual',
#  'LLaMEA-new_individual',
#  'LLaMEA-full_ensamble',
#  'LLaMEA-small_mutation']
# ['MA_BBOB']

# %%
plot_convergence(logger, metric="AOCC", save=False, budget=10)

# %%
plot_experiment_CEG(logger, save=False, budget=16, max_seeds=10)

# %% [markdown]
# ### Fitness Table
# * `iohblade` also comes with a fitness table logger, and different ways to plot the fitness of the population for each method used.

# %%
from iohblade.plots import fitness_table

fitness_table(logger)
# Out:
#                                                    MA_BBOB
# LLaMEA-fine-mutation                 0.70 ± 0.10 (p=0.995)
# LLaMEA-fine-mutation+new_individual  0.70 ± 0.03 (p=0.995)
# LLaMEA-full_ensamble                 0.55 ± 0.13 (p=0.597)
# LLaMEA-new_individual                0.25 ± 0.14 (p=0.259)
# LLaMEA-small_mutation                0.65 ± 0.05 (p=0.683)

# %%
from iohblade.plots import plot_boxplot_fitness
plot_boxplot_fitness(logger)

# %%
# This one really needs some work.
from iohblade.plots import plot_boxplot_fitness_hue
plot_boxplot_fitness_hue(logger)

# %% [markdown]
# ### Plot Token Usage.
# * Since we are relying on LLM to generate new algorithms, keeping a track of the tokens used, is also important.
# * `iohblade` provides a feature to measure and log the amount of tokens used as well.

# %%
from iohblade.plots import plot_token_usage
from IPython.display import Image

plot_token_usage(logger)      # <--- Stores image in logger directory named `token_usage.png`.
display(Image(filename=logger.dirname + '/token_usage.png'))

# %% [markdown]
# # BLADE-Web Application
# * `iohblade` also comes with a `stream-lit` web application, which can be used to view convergence plot of completed tasks, download best code solutions, and monitor ongoing tasks. Just use:
# ```bash
# $: uv run iohblade-webapp
# ```
